# %% [markdown]
# # Denoising Images with an Encoder-Decoder
#
# This notebook provides you with a complete code example that generates noisy brightfield microscopy images of particles, trains an encoder-decoder to denoise them, and visualizes the results.

# %% [markdown]
# ## Generating the Data
#
# Define a spherical particle ...

# %%
import deeptrack as dt
import numpy as np

particle = dt.Sphere(
    position=np.array([0.5, 0.5]) * 64,
    position_unit="pixel",
    radius=500 * dt.units.nm,
    refractive_index=1.45 + 0.02j,
)

# %% [markdown]
# ... define the microscope to observe the particle ...

# %%
brightfield_microscope = dt.Brightfield(
    wavelength=500 * dt.units.nm,
    NA=1,
    resolution=1 * dt.units.um,
    magnification=10,
    refractive_index_medium=1.33,
    upsample=2,
    output_region=(0, 0, 64, 64),
)

# %% [markdown]
# ... obtain the image of the microscopic particle ...

# %%
illuminated_sample = brightfield_microscope(particle)

# %% [markdown]
# ... simulate the clean image of the particle ...

# %%
import torch

clean_particle = (
    illuminated_sample
    >> dt.NormalizeMinMax()
    >> dt.MoveAxis(2, 0)
    >> dt.pytorch.ToTensor(dtype=torch.float)
)

# %% [markdown]
# ... simulate the noisy image of the particle ...

# %%
noise = dt.Poisson(snr=lambda: 2.0 + np.random.rand())

noisy_particle = (
    illuminated_sample
    >> noise
    >> dt.NormalizeMinMax()
    >> dt.MoveAxis(2, 0)
    >> dt.pytorch.ToTensor(dtype=torch.float)
)

# %% [markdown]
# ... combine the noisy and clean particle images into a single simulation pipeline ...

# %%
pipeline = noisy_particle & clean_particle

# %% [markdown]
# ... and plot a few noisy and corresponding clean particle images.

# %%
import matplotlib.pyplot as plt

def plot_image(title, image):
    """Plot a grayscale image with a title."""
    plt.imshow(image, cmap="gray")
    plt.title(title, fontsize=24)
    plt.axis("off")
    plt.show()

# %%
for i in range(5):
    input, target = pipeline.update().resolve()
    plot_image(f"Input Image {i}", input.permute(1, 2, 0))      # heigh, width, channel
    plot_image(f"Target Image {i}", target.permute(1, 2, 0))

# %% [markdown]
# ## Creating a Dataset
#
# Define a class representing a simulated dataset to generate the data for the training of the denoising encoder-decoder ...

# %%
from torch.utils.data import Dataset

class SimulatedDataset(Dataset):
    """Simulated dataset generating pairs of noisy and clean images."""
    
    def __init__(self, pipeline, buffer_size, replace=0):
        """Initialize the dataset."""
        self.pipeline = pipeline
        self.buffer_size = buffer_size
        self.replace = replace
        self.images = [pipeline.update().resolve() for _ in range(buffer_size)]
        
    def __len__(self):
        """Return the size of the dataset buffer."""
        return self.buffer_size

    def __getitem__(self, idx):
        """Retrieve a noisy-clean image pair from the dataset."""
        if np.random.rand() < self.replace:
            self.images[idx] = self.pipeline.update().resolve()
        image_pair = self.images[idx]
        noisy_image, clean_image = image_pair[0], image_pair[1]
        return noisy_image, clean_image

# %% [markdown]
# ... and create the dataset and the data loader.

# %%
from torch.utils.data import DataLoader

dataset = SimulatedDataset(pipeline, buffer_size=256, replace=0.1)
loader = DataLoader(dataset, batch_size=8, shuffle=True)        # load 8 images each time, and shuffle the order for training

# %% [markdown]
# ## Defining and Training the Encoder-Decoder
#
# Define the encoder-decoder ...

# %%
import deeplay as dl

ed = dl.ConvolutionalEncoderDecoder2d(
    in_channels=1,                          # -> grey scale 
    encoder_channels=[16, 16],
    decoder_channels=[16, 16],
    out_channels=1,
)

print(ed)
# Out:
# ConvolutionalEncoderDecoder2d(
#   (encoder): ConvolutionalEncoder2d(
#     (blocks): LayerList(
#       (0): PoolLayerActivationNormalization(
#         (pool): Layer[Identity]()
#         (layer): Layer[Conv2d](in_channels=1, out_channels=16, kernel_size=3, stride=1, padding=1)
#         (activation): Layer[ReLU]()
#         (normalization): Layer[Identity](num_features=16)
#       )
#       (1-2): 2 x PoolLayerActivationNormalization(
#         (pool): Layer[MaxPool2d](kernel_size=2)
#         (layer): Layer[Conv2d](in_channels=16, out_channels=16, kernel_size=3, stride=1, padding=1)
#         (activation): Layer[ReLU]()
#         (normalization): Layer[Identity](num_features=16)
#       )
#     )
#     (postprocess): Layer[Identity]()
#   )
#   (decoder): ConvolutionalDecoder2d(
#     (preprocess): Layer[Identity]()
#     (blocks): LayerList(
#       (0-1): 2 x LayerActivationNormalizationUpsample(
#         (layer): Layer[Conv2d](in_channels=16, out_channels=16, kernel_size=3, stride=1, padding=1)
#         (activation): Layer[ReLU]()
#         (normalization): Layer[Identity](num_features=16)
#         (upsample): Layer[ConvTranspose2d](in_channels=16, out_channels=16, kernel_size=2, stride=2)
#       )
#       (2): LayerActivationNormalizationUpsample(
#         (layer): Layer[Conv2d](in_channels=16, out_channels=1, kernel_size=3, stride=1, padding=1)
#         (activation): Layer[Sigmoid]()
#         (normalization): Layer[Identity](num_features=1)
#         (upsample): Layer[Identity]()
#       )
#     )
#   )
#   (blocks): ModuleList(
#     (0): PoolLayerActivationNormalization(
#       (pool): Layer[Identity]()
#       (layer): Layer[Conv2d](in_channels=1, out_channels=16, kernel_size=3, stride=1, padding=1)
#       (activation): Layer[ReLU]()
#       (normalization): Layer[Identity](num_features=16)
#     )
#     (1-2): 2 x PoolLayerActivationNormalization(
#       (pool): Layer[MaxPool2d](kernel_size=2)
#       (layer): Layer[Conv2d](in_channels=16, out_channels=16, kernel_size=3, stride=1, padding=1)
#       (activation): Layer[ReLU]()
#       (normalization): Layer[Identity](num_features=16)
#     )
#     (3-4): 2 x LayerActivationNormalizationUpsample(
#       (layer): Layer[Conv2d](in_channels=16, out_channels=16, kernel_size=3, stride=1, padding=1)
#       (activation): Layer[ReLU]()
#       (normalization): Layer[Identity](num_features=16)
#       (upsample): Layer[ConvTranspose2d](in_channels=16, out_channels=16, kernel_size=2, stride=2)
#     )
#     (5): LayerActivationNormalizationUpsample(
#       (layer): Layer[Conv2d](in_channels=16, out_channels=1, kernel_size=3, stride=1, padding=1)
#       (activation): Layer[Sigmoid]()
#       (normalization): Layer[Identity](num_features=1)
#       (upsample): Layer[Identity]()
#     )
#   )
# )

# %% [markdown]
# ... compile it ...

# %%
from torch.nn import L1Loss

regressor_template = dl.Regressor(model=ed, loss=L1Loss(), optimizer=dl.Adam())
ed_regressor = regressor_template.create()

print(ed_regressor)
# Out:
# Regressor(
#   (loss): L1Loss()
#   (train_metrics): MetricCollection,
#     prefix=train
#   )
#   (val_metrics): MetricCollection,
#     prefix=val
#   )
#   (test_metrics): MetricCollection,
#     prefix=test
#   )
#   (model): ConvolutionalEncoderDecoder2d(
#     (encoder): ConvolutionalEncoder2d(
#       (blocks): LayerList(
#         (0): PoolLayerActivationNormalization(
#           (pool): Identity()
#           (layer): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (activation): ReLU()
#           (normalization): Identity()
#         )
#         (1-2): 2 x PoolLayerActivationNormalization(
#           (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (layer): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (activation): ReLU()
#           (normalization): Identity()
#         )
#       )
#       (postprocess): Identity()
#     )
#     (decoder): ConvolutionalDecoder2d(
#       (preprocess): Identity()
#       (blocks): LayerList(
#         (0-1): 2 x LayerActivationNormalizationUpsample(
#           (layer): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (activation): ReLU()
#           (normalization): Identity()
#           (upsample): ConvTranspose2d(16, 16, kernel_size=(2, 2), stride=(2, 2))
#         )
#         (2): LayerActivationNormalizationUpsample(
#           (layer): Conv2d(16, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (activation): Sigmoid()
#           (normalization): Identity()
#           (upsample): Identity()
#         )
#       )
#     )
#     (blocks): ModuleList(
#       (0): PoolLayerActivationNormalization(
#         (pool): Identity()
#         (layer): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (activation): ReLU()
#         (normalization): Identity()
#       )
#       (1-2): 2 x PoolLayerActivationNormalization(
#         (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (layer): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (activation): ReLU()
#         (normalization): Identity()
#       )
#       (3-4): 2 x LayerActivationNormalizationUpsample(
#         (layer): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (activation): ReLU()
#         (normalization): Identity()
#         (upsample): ConvTranspose2d(16, 16, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (5): LayerActivationNormalizationUpsample(
#         (layer): Conv2d(16, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (activation): Sigmoid()
#         (normalization): Identity()
#         (upsample): Identity()
#       )
#     )
#   )
#   (optimizer): Adam[Adam]()
# )

# %% [markdown]
# ... and train it.

# %%
ed_trainer = dl.Trainer(max_epochs=100, accelerator="auto")
ed_trainer.fit(ed_regressor, loader)
# Out:
# /opt/homebrew/lib/python3.11/site-packages/lightning/pytorch/trainer/configuration_validator.py:74: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
# INFO:
#   | Name          | Type                          | Params
# ----------------------------------------------------------------
# 0 | loss          | L1Loss                        | 0
# 1 | train_metrics | MetricCollection              | 0
# 2 | val_metrics   | MetricCollection              | 0
# 3 | test_metrics  | MetricCollection              | 0
# 4 | model         | ConvolutionalEncoderDecoder2d | 11.7 K
# 5 | optimizer     | Adam                          | 0
# ----------------------------------------------------------------
# 11.7 K    Trainable params
# 0         Non-trainable params
# 11.7 K    Total params
# 0.047     Total estimated model params size (MB)
# INFO:lightning.pytorch.callbacks.model_summary:
#   | Name          | Type                          | Params
# ----------------------------------------------------------------
# 0 | loss          | L1Loss                        | 0
# 1 | train_metrics | MetricCollection              | 0
# 2 | val_metrics   | MetricCollection              | 0
# 3 | test_metrics  | MetricCollection              | 0
# 4 | model         | ConvolutionalEncoderDecoder2d | 11.7 K
# 5 | optimizer     | Adam                          | 0
# ----------------------------------------------------------------
# 11.7 K    Trainable params
# 0         Non-trainable params
# 11.7 K    Total params
# 0.047     Total estimated model params size (MB)
# /opt/homebrew/lib/python3.11/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=7` in the `DataLoader` to improve performance.
# /opt/homebrew/lib/python3.11/site-packages/lightning/pytorch/loops/fit_loop.py:298: The number of training batches (32) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]

# %% [markdown]
# ## Testing the Trained Encoder-Decoder

# %%
for i in range(5):
    input, target = pipeline.update().resolve()
    predicted = ed_regressor(input.unsqueeze(0)).detach()

    plot_image(f"Input Image {i}", input[0, :, :])
    plot_image(f"Target Image {i}", target[0, :, :])
    plot_image(f"Predicted Image {1}", predicted[0, 0, :, :])

# %% [markdown]
# As all Outputs are the same we have the phenomenon of mode collapses. The NN disregards the inputs. Normalizing the input helps therefore.

# %% [markdown]
# ## Checking Absence of Mode Collapse
#
# Use the trained encoder-decoder with a blank image.

# %%
blank = brightfield_microscope(particle ^ 0)
blank_pipeline = (
    blank
    >> noise
    >> dt.NormalizeMinMax()
    >> dt.MoveAxis(2, 0)
    >> dt.pytorch.ToTensor(dtype=torch.float)
)

for i in range(2):
    blank_image = blank_pipeline.update().resolve()
    blank_predicted = ed_regressor(blank_image.unsqueeze(0)).detach()
    plot_image(f"Input Image {i}", blank_image[0, :, :])
    plot_image(f"Predicted Image {i}", np.square(blank_predicted[0, 0, :, :]))

# %% [markdown]
# ## Checking Generalization Capabilities
#
# Define a pipeline with a particle with varying position and radius ...

# %%
diverse_particle = dt.Sphere(
    position=lambda: np.array([0.2, 0.2] + np.random.rand(2) * 0.6) * 64,
    position_unit="pixel",
    radius=lambda: 500 * dt.units.nm * (1 + np.random.rand()),
    refractive_index=1.45 + 0.02j,
)
diverse_illuminated_sample = brightfield_microscope(diverse_particle)
diverse_clean_particle = (
    diverse_illuminated_sample
    >> dt.NormalizeMinMax()
    >> dt.MoveAxis(2, 0)
    >> dt.pytorch.ToTensor(dtype=torch.float)
)
diverse_noisy_particle = (
    diverse_illuminated_sample
    >> noise
    >> dt.NormalizeMinMax()
    >> dt.MoveAxis(2, 0)
    >> dt.pytorch.ToTensor(dtype=torch.float)
)

diverse_pipeline = diverse_noisy_particle & diverse_clean_particle

# %% [markdown]
# ... and denoise images of diverse particles using the trained encoder-decoder.

# %%
for i in range(5):
    diverse_input, diverse_target = diverse_pipeline.update().resolve()
    diverse_predicted = ed_regressor(diverse_input.unsqueeze(0)).detach()

    plot_image(f"Input Image {i}", diverse_input[0, :, :])
    plot_image(f"Target Image {i}", diverse_target[0, :, :])
    plot_image(f"Predicted Image {1}", diverse_predicted[0, 0, :, :])

# %% [markdown]
# ## Improving the Training
#
# Train with the dataset with varying parameters ...

# %%
diverse_dataset = SimulatedDataset(diverse_pipeline, buffer_size=256,
                                   replace=0.1)
diverse_loader = DataLoader(diverse_dataset, batch_size=8, shuffle=True)
diverse_ed_regressor = regressor_template.create()
diverse_ed_trainer = dl.Trainer(max_epochs=100, accelerator="auto")
diverse_ed_trainer.fit(diverse_ed_regressor, diverse_loader)
# Out:
# INFO:
#   | Name          | Type                          | Params
# ----------------------------------------------------------------
# 0 | loss          | L1Loss                        | 0
# 1 | train_metrics | MetricCollection              | 0
# 2 | val_metrics   | MetricCollection              | 0
# 3 | test_metrics  | MetricCollection              | 0
# 4 | model         | ConvolutionalEncoderDecoder2d | 11.7 K
# 5 | optimizer     | Adam                          | 0
# ----------------------------------------------------------------
# 11.7 K    Trainable params
# 0         Non-trainable params
# 11.7 K    Total params
# 0.047     Total estimated model params size (MB)
# INFO:lightning.pytorch.callbacks.model_summary:
#   | Name          | Type                          | Params
# ----------------------------------------------------------------
# 0 | loss          | L1Loss                        | 0
# 1 | train_metrics | MetricCollection              | 0
# 2 | val_metrics   | MetricCollection              | 0
# 3 | test_metrics  | MetricCollection              | 0
# 4 | model         | ConvolutionalEncoderDecoder2d | 11.7 K
# 5 | optimizer     | Adam                          | 0
# ----------------------------------------------------------------
# 11.7 K    Trainable params
# 0         Non-trainable params
# 11.7 K    Total params
# 0.047     Total estimated model params size (MB)
# Training: |          | 0/? [00:00<?, ?it/s]

# %% [markdown]
# ... and plot the images obtained with the improved training.

# %%
for i in range(5):
    diverse_input, diverse_target = diverse_pipeline.update().resolve()
    diverse_predicted = diverse_ed_regressor(diverse_input.unsqueeze(0)).detach()

    plot_image(f"Input Image {i}", diverse_input[0, :, :])
    plot_image(f"Target Image {i}", diverse_target[0, :, :])
    plot_image(f"Predicted Image {1}", diverse_predicted[0, 0, :, :])

# %% [markdown]
# ## Improving the Encoder-Decoder
#
# Define an improved encoder-decoder ...

# %%
better_ed = dl.ConvolutionalEncoderDecoder2d(
    in_channels=1,
    encoder_channels=[32, 64, 128],
    decoder_channels=[128, 64, 32],
    out_channels=1,
)

print(better_ed)
# Out:
# ConvolutionalEncoderDecoder2d(
#   (encoder): ConvolutionalEncoder2d(
#     (blocks): LayerList(
#       (0): PoolLayerActivationNormalization(
#         (pool): Layer[Identity]()
#         (layer): Layer[Conv2d](in_channels=1, out_channels=32, kernel_size=3, stride=1, padding=1)
#         (activation): Layer[ReLU]()
#         (normalization): Layer[Identity](num_features=32)
#       )
#       (1): PoolLayerActivationNormalization(
#         (pool): Layer[MaxPool2d](kernel_size=2)
#         (layer): Layer[Conv2d](in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1)
#         (activation): Layer[ReLU]()
#         (normalization): Layer[Identity](num_features=64)
#       )
#       (2): PoolLayerActivationNormalization(
#         (pool): Layer[MaxPool2d](kernel_size=2)
#         (layer): Layer[Conv2d](in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1)
#         (activation): Layer[ReLU]()
#         (normalization): Layer[Identity](num_features=128)
#       )
#       (3): PoolLayerActivationNormalization(
#         (pool): Layer[MaxPool2d](kernel_size=2)
#         (layer): Layer[Conv2d](in_channels=128, out_channels=128, kernel_size=3, stride=1, padding=1)
#         (activation): Layer[ReLU]()
#         (normalization): Layer[Identity](num_features=128)
#       )
#     )
#     (postprocess): Layer[Identity]()
#   )
#   (decoder): ConvolutionalDecoder2d(
#     (preprocess): Layer[Identity]()
#     (blocks): LayerList(
#       (0): LayerActivationNormalizationUpsample(
#         (layer): Layer[Conv2d](in_channels=128, out_channels=128, kernel_size=3, stride=1, padding=1)
#         (activation): Layer[ReLU]()
#         (normalization): Layer[Identity](num_features=128)
#         (upsample): Layer[ConvTranspose2d](in_channels=128, out_channels=128, kernel_size=2, stride=2)
#       )
#       (1): LayerActivationNormalizationUpsample(
#         (layer): Layer[Conv2d](in_channels=128, out_channels=64, kernel_size=3, stride=1, padding=1)
#         (activation): Layer[ReLU]()
#         (normalization): Layer[Identity](num_features=64)
#         (upsample): Layer[ConvTranspose2d](in_channels=64, out_channels=64, kernel_size=2, stride=2)
#       )
#       (2): LayerActivationNormalizationUpsample(
#         (layer): Layer[Conv2d](in_channels=64, out_channels=32, kernel_size=3, stride=1, padding=1)
#         (activation): Layer[ReLU]()
#         (normalization): Layer[Identity](num_features=32)
#         (upsample): Layer[ConvTranspose2d](in_channels=32, out_channels=32, kernel_size=2, stride=2)
#       )
#       (3): LayerActivationNormalizationUpsample(
#         (layer): Layer[Conv2d](in_channels=32, out_channels=1, kernel_size=3, stride=1, padding=1)
#         (activation): Layer[Sigmoid]()
#         (normalization): Layer[Identity](num_features=1)
#         (upsample): Layer[Identity]()
#       )
#     )
#   )
#   (blocks): ModuleList(
#     (0): PoolLayerActivationNormalization(
#       (pool): Layer[Identity]()
#       (layer): Layer[Conv2d](in_channels=1, out_channels=32, kernel_size=3, stride=1, padding=1)
#       (activation): Layer[ReLU]()
#       (normalization): Layer[Identity](num_features=32)
#     )
#     (1): PoolLayerActivationNormalization(
#       (pool): Layer[MaxPool2d](kernel_size=2)
#       (layer): Layer[Conv2d](in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1)
#       (activation): Layer[ReLU]()
#       (normalization): Layer[Identity](num_features=64)
#     )
#     (2): PoolLayerActivationNormalization(
#       (pool): Layer[MaxPool2d](kernel_size=2)
#       (layer): Layer[Conv2d](in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1)
#       (activation): Layer[ReLU]()
#       (normalization): Layer[Identity](num_features=128)
#     )
#     (3): PoolLayerActivationNormalization(
#       (pool): Layer[MaxPool2d](kernel_size=2)
#       (layer): Layer[Conv2d](in_channels=128, out_channels=128, kernel_size=3, stride=1, padding=1)
#       (activation): Layer[ReLU]()
#       (normalization): Layer[Identity](num_features=128)
#     )
#     (4): LayerActivationNormalizationUpsample(
#       (layer): Layer[Conv2d](in_channels=128, out_channels=128, kernel_size=3, stride=1, padding=1)
#       (activation): Layer[ReLU]()
#       (normalization): Layer[Identity](num_features=128)
#       (upsample): Layer[ConvTranspose2d](in_channels=128, out_channels=128, kernel_size=2, stride=2)
#     )
#     (5): LayerActivationNormalizationUpsample(
#       (layer): Layer[Conv2d](in_channels=128, out_channels=64, kernel_size=3, stride=1, padding=1)
#       (activation): Layer[ReLU]()
#       (normalization): Layer[Identity](num_features=64)
#       (upsample): Layer[ConvTranspose2d](in_channels=64, out_channels=64, kernel_size=2, stride=2)
#     )
#     (6): LayerActivationNormalizationUpsample(
#       (layer): Layer[Conv2d](in_channels=64, out_channels=32, kernel_size=3, stride=1, padding=1)
#       (activation): Layer[ReLU]()
#       (normalization): Layer[Identity](num_features=32)
#       (upsample): Layer[ConvTranspose2d](in_channels=32, out_channels=32, kernel_size=2, stride=2)
#     )
#     (7): LayerActivationNormalizationUpsample(
#       (layer): Layer[Conv2d](in_channels=32, out_channels=1, kernel_size=3, stride=1, padding=1)
#       (activation): Layer[Sigmoid]()
#       (normalization): Layer[Identity](num_features=1)
#       (upsample): Layer[Identity]()
#     )
#   )
# )

# %% [markdown]
# ... compile it ...

# %%
better_regressor_template = dl.Regressor(
model=better_ed,
loss=L1Loss(),
optimizer=dl.Adam(),
)
better_ed_regressor = better_regressor_template.create()

print(better_ed_regressor)
# Out:
# Regressor(
#   (loss): L1Loss()
#   (train_metrics): MetricCollection,
#     prefix=train
#   )
#   (val_metrics): MetricCollection,
#     prefix=val
#   )
#   (test_metrics): MetricCollection,
#     prefix=test
#   )
#   (model): ConvolutionalEncoderDecoder2d(
#     (encoder): ConvolutionalEncoder2d(
#       (blocks): LayerList(
#         (0): PoolLayerActivationNormalization(
#           (pool): Identity()
#           (layer): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (activation): ReLU()
#           (normalization): Identity()
#         )
#         (1): PoolLayerActivationNormalization(
#           (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (layer): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (activation): ReLU()
#           (normalization): Identity()
#         )
#         (2): PoolLayerActivationNormalization(
#           (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (layer): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (activation): ReLU()
#           (normalization): Identity()
#         )
#         (3): PoolLayerActivationNormalization(
#           (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (layer): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (activation): ReLU()
#           (normalization): Identity()
#         )
#       )
#       (postprocess): Identity()
#     )
#     (decoder): ConvolutionalDecoder2d(
#       (preprocess): Identity()
#       (blocks): LayerList(
#         (0): LayerActivationNormalizationUpsample(
#           (layer): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (activation): ReLU()
#           (normalization): Identity()
#           (upsample): ConvTranspose2d(128, 128, kernel_size=(2, 2), stride=(2, 2))
#         )
#         (1): LayerActivationNormalizationUpsample(
#           (layer): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (activation): ReLU()
#           (normalization): Identity()
#           (upsample): ConvTranspose2d(64, 64, kernel_size=(2, 2), stride=(2, 2))
#         )
#         (2): LayerActivationNormalizationUpsample(
#           (layer): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (activation): ReLU()
#           (normalization): Identity()
#           (upsample): ConvTranspose2d(32, 32, kernel_size=(2, 2), stride=(2, 2))
#         )
#         (3): LayerActivationNormalizationUpsample(
#           (layer): Conv2d(32, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (activation): Sigmoid()
#           (normalization): Identity()
#           (upsample): Identity()
#         )
#       )
#     )
#     (blocks): ModuleList(
#       (0): PoolLayerActivationNormalization(
#         (pool): Identity()
#         (layer): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (activation): ReLU()
#         (normalization): Identity()
#       )
#       (1): PoolLayerActivationNormalization(
#         (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (layer): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (activation): ReLU()
#         (normalization): Identity()
#       )
#       (2): PoolLayerActivationNormalization(
#         (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (layer): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (activation): ReLU()
#         (normalization): Identity()
#       )
#       (3): PoolLayerActivationNormalization(
#         (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (layer): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (activation): ReLU()
#         (normalization): Identity()
#       )
#       (4): LayerActivationNormalizationUpsample(
#         (layer): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (activation): ReLU()
#         (normalization): Identity()
#         (upsample): ConvTranspose2d(128, 128, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (5): LayerActivationNormalizationUpsample(
#         (layer): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (activation): ReLU()
#         (normalization): Identity()
#         (upsample): ConvTranspose2d(64, 64, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (6): LayerActivationNormalizationUpsample(
#         (layer): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (activation): ReLU()
#         (normalization): Identity()
#         (upsample): ConvTranspose2d(32, 32, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (7): LayerActivationNormalizationUpsample(
#         (layer): Conv2d(32, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (activation): Sigmoid()
#         (normalization): Identity()
#         (upsample): Identity()
#       )
#     )
#   )
#   (optimizer): Adam[Adam]()
# )

# %% [markdown]
# ... train it ...

# %%
better_ed_trainer = dl.Trainer(max_epochs=150, accelerator="auto")
better_ed_trainer.fit(better_ed_regressor, diverse_loader)
# Out:
# INFO:
#   | Name          | Type                          | Params
# ----------------------------------------------------------------
# 0 | loss          | L1Loss                        | 0
# 1 | train_metrics | MetricCollection              | 0
# 2 | val_metrics   | MetricCollection              | 0
# 3 | test_metrics  | MetricCollection              | 0
# 4 | model         | ConvolutionalEncoderDecoder2d | 566 K
# 5 | optimizer     | Adam                          | 0
# ----------------------------------------------------------------
# 566 K     Trainable params
# 0         Non-trainable params
# 566 K     Total params
# 2.266     Total estimated model params size (MB)
# INFO:lightning.pytorch.callbacks.model_summary:
#   | Name          | Type                          | Params
# ----------------------------------------------------------------
# 0 | loss          | L1Loss                        | 0
# 1 | train_metrics | MetricCollection              | 0
# 2 | val_metrics   | MetricCollection              | 0
# 3 | test_metrics  | MetricCollection              | 0
# 4 | model         | ConvolutionalEncoderDecoder2d | 566 K
# 5 | optimizer     | Adam                          | 0
# ----------------------------------------------------------------
# 566 K     Trainable params
# 0         Non-trainable params
# 566 K     Total params
# 2.266     Total estimated model params size (MB)
# Training: |          | 0/? [00:00<?, ?it/s]

# %% [markdown]
# ... and plot the images obtained with the improved encoder-decoder.

# %%
for i in range(5):
    diverse_input, diverse_target = diverse_pipeline.update().resolve()
    diverse_predicted = better_ed_regressor(diverse_input.unsqueeze(0)).detach()

    plot_image(f"Input Image {i}", diverse_input[0, :, :])
    plot_image(f"Target Image {i}", diverse_target[0, :, :])
    plot_image(f"Predicted Image {1}", diverse_predicted[0, 0, :, :])
