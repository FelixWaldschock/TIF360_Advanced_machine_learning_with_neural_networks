# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
import json
# in the "/logfiles" directory get the last timestamp


plt.style.use('science')


# def readBestRewardValue():
#     with open("logfiles/conf/log.json", "r") as file:
#         data = json.load(file)
#         return str(data["index"])

# label = readBestRewardValue()

# %%
def numberOfZerosInQ(table):
    count = 0
    for i in range(len(table)):
        for j in range(len(table[i])):
            if table[i][j] == 0:
                count += 1
    return count

def numberOfVisitedStates(table):
    count = 0
    tmp = np.sum(table, axis=1)
    count = np.nonzero(tmp)[0].shape[0]
    return count

# %% [markdown]
# Exercise a:

# %%
label = "4_1000"
label = str(label)


# load the rewards from the /logfiles
folder = "logfiles/"
rewards = np.load(folder + "rewards_" + str(label) + ".npy")
gameLength = np.load(folder + "gameLengthTracker_" + str(label) + ".npy")
actions = np.load(folder + "actionTracker_" + str(label) + ".npy")
Q = np.load(folder + "Q-table_" + str(label) + ".npy")

# %%
def computeMovingAverage(rewards):
    rewardsAverage = []
    averageLength = 100
    for i in range(len(rewards)):
        if i < averageLength:
            rewardsAverage.append(np.mean(rewards[:i]))
        else:
            rewardsAverage.append(np.mean(rewards[i-averageLength:i]))
    return rewardsAverage

# %%
# get rid of the last 10 episodes
rewards = rewards[:-1]
plt.figure(figsize=(6, 4))
plt.plot(rewards, label='rewards')
plt.plot(computeMovingAverage(rewards=rewards), label='rewards average')
plt.plot(gameLength, label='game length')
plt.title('Rewards over time - Simulation: ' + label + " Parameters a)")
plt.xlabel('Episodes')
plt.ylabel('Rewards')
plt.grid('minor')
plt.legend()

print("Number of zeros in Q: ", numberOfZerosInQ(Q))
print("Number of visited states: ", numberOfVisitedStates(Q))
# Out:
# /opt/homebrew/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/homebrew/lib/python3.11/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Number of zeros in Q:  4193433
# Number of visited states:  95

# %% [markdown]
# Assignment b:

# %%
label = "1_10000"
label = str(label)

# load the rewards from the /logfiles
folder = "logfiles/assignmentLogs/"
folder = "logfiles/"
rewards = np.load(folder + "rewards_" + str(label) + ".npy")
gameLength = np.load(folder + "gameLengthTracker_" + str(label) + ".npy")
actions = np.load(folder + "actionTracker_" + str(label) + ".npy")
Q = np.load(folder + "Q-table_" + str(label) + ".npy")

# %%
# get rid of the last 10 episodes
rewards = rewards[:-1]
plt.figure(figsize=(6, 4))
plt.plot(rewards, label='rewards')
plt.plot(computeMovingAverage(rewards=rewards), label='rewards average')
plt.plot(gameLength, label='game length')
plt.title('Rewards over time - Simulation: ' + label + " Parameters b)")
plt.xlabel('Episodes')
plt.xlabel('Episodes')
plt.ylabel('Rewards')
plt.grid('minor')
plt.xlim(0, 15000)
plt.legend()

print("Number of zeros in Q: ", numberOfZerosInQ(Q))
print("Number of visited states: ", numberOfVisitedStates(Q))
# Out:
# /opt/homebrew/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/homebrew/lib/python3.11/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Number of zeros in Q:  4192903
# Number of visited states:  194

# %%
print(gameLength)
# Out:
# [ 3  3  3 ... 50 50 50]

# %% [markdown]
# c)

# %%
label = "3_200000"
label = str(label)

# load the rewards from the /logfiles
folder = "logfiles/assignmentLogs/"
folder = "logfiles/"
rewards = np.load(folder + "rewards_" + str(label) + ".npy")
gameLength = np.load(folder + "gameLengthTracker_" + str(label) + ".npy")
actions = np.load(folder + "actionTracker_" + str(label) + ".npy")
Q = np.load(folder + "Q-table_" + str(label) + ".npy")

# %%
# get rid of the last 10 episodes
rewards = rewards[:-1]
plt.figure(figsize=(6, 4))
plt.plot(rewards, label='rewards')
plt.plot(computeMovingAverage(rewards=rewards), label='rewards average')
plt.plot(gameLength, label='game length')
plt.title('Rewards over time - Simulation: ' + label+ " Parameters c)")
plt.xlabel('Episodes')
plt.xlabel('Episodes')
plt.ylabel('Rewards')
plt.grid('minor')
plt.legend()

print("Number of zeros in Q: ", numberOfZerosInQ(Q))
print("Number of visited states: ", numberOfVisitedStates(Q))
# Out:
# Number of zeros in Q:  4067426
# Number of visited states:  13300

# %% [markdown]
# d)

# %%
label = "DQDQN_10000"
label = str(label)

# load the rewards from the /logfiles
folder = "logfiles/assignmentLogs/"
folder = "logfiles/"
rewards = np.load(folder + "rewards_" + str(label) + ".npy")
gameLength = np.load(folder + "gameLengthTracker_" + str(label) + ".npy")

# %%
# get rid of the last 10 episodes
rewards = rewards[:-1]
plt.figure(figsize=(6, 4))
plt.plot(rewards, label='rewards')
plt.plot(computeMovingAverage(rewards=rewards), label='rewards average')
# plt.plot(gameLength, label='game length')
plt.title('Rewards over time - Simulation: ' + label+ " Parameters 2a)")
plt.xlabel('Episodes')
plt.xlabel('Episodes')
plt.ylabel('Rewards')
plt.grid('minor')
plt.legend()
